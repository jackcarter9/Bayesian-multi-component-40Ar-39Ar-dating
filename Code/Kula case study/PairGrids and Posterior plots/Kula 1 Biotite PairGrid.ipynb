# %%
import numpy as np 
import seaborn as sns 
import os 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
# Get data
cwd = os.chdir('/Users/danbarfod/Downloads/Kula_Biotite')

# %%
df = pd.read_csv('Kula_biotite_1_trace.csv')

# %%
df.tail()
# Out:
#        Unnamed: 0         ea1         ea2    phi__0    phi__1       d01  \
# 39995       39995  196.005018  188.538809  0.259782  0.740218  0.300247
# 39996       39996  196.810220  191.355238  0.267922  0.732078  0.300247
# 39997       39997  196.949717  188.199727  0.211665  0.788335  0.387125
# 39998       39998  195.159026  188.334786  0.245666  0.754334  0.429374
# 39999       39999  197.939921  188.334786  0.222646  0.777354  0.434176
#
#             d02        a1        a2       age1  ...  age_error_m__4  \
# 39995  0.605814  0.008186  0.008130   7.718333  ...       12.902188
# 39996  0.674023  0.008695  0.008080   5.554255  ...       15.787916
# 39997  0.702564  0.008022  0.008080   9.133408  ...       16.718991
# 39998  0.702564  0.011722  0.008042  23.915201  ...       25.073446
# 39999  0.702564  0.009322  0.008127  19.067566  ...       16.443561
#
#        age_error_m__5  age_error_m__6  age_error_m__7  age_error_m__8  \
# 39995        4.926783       16.954401       14.037892       13.318797
# 39996        5.460491       15.819902       15.054775       10.978552
# 39997        6.296624       16.882420       11.316252       14.817116
# 39998        3.955362       12.868397       14.723161       12.583302
# 39999        4.306905       16.285314       14.864537       11.060044
#
#        age_error_m__9  age_error_m__10  age_error_m__11  age_error_m__12  \
# 39995        5.607925        12.790151        13.167739        11.050541
# 39996        6.874423        17.857038        13.794241        13.100269
# 39997        6.499531        15.974053        13.760032        13.072287
# 39998        9.582613        14.665730        16.295587        12.760512
# 39999       13.069062        19.358068        13.984072        10.571511
#
#        age_error_m__13
# 39995        26.635352
# 39996        23.955940
# 39997        26.157254
# 39998        33.927986
# 39999        40.938021
#
# [5 rows x 68 columns]

# %%
# Create the plotting dataframe 

dfp = pd.DataFrame({"age1": df['age1'].values, 
                   "age2": df['age2'].values, 
                   "ea1": df['ea1'].values, 
                   "ea2": df['ea2'].values, 
                   "d01": df['d01'].values, 
                   "d02": df['d02'].values})

# %%
dfp.head()
# Out:
#         age1        age2         ea1         ea2       d01       d02
# 0  81.632200  136.196727  191.160963  184.596045  0.267695  0.693306
# 1  85.965785  137.434742  195.488604  185.577399  0.236338  0.790714
# 2  77.677889  137.434742  197.179109  185.577399  0.337619  0.790714
# 3  90.607136  138.740603  195.385817  182.187417  0.332664  0.790714
# 4  91.252485  140.773435  191.589828  182.187417  0.458659  0.827878

# %%
np.std(dfp['age1'].values)
# Out:
# 12.733981552878076

# %%
# PairGrid
g = sns.PairGrid(dfp[-5000::4])

g.map_diag(plt.hist, facecolor = 'grey', 
          edgecolor = 'k', 
          alpha = 0.4,)


g.map_offdiag(plt.scatter, 
             alpha = 0.1, 
             color = 'k')

#Y axis label
g.axes[0,0].set_ylabel('Age$_{1}$ (Ma)');
g.axes[1,0].set_ylabel('Age$_{2}$ (Ma)');
g.axes[2,0].set_ylabel('E$_{a_1}$ (kJmol$^{-1}$)');
g.axes[3,0].set_ylabel('E$_{a_2}$ (kJmol$^{-1}$)');
g.axes[4,0].set_ylabel('D$_{0_1}$ ($cm^{2}$s$^{-1}$)');
g.axes[5,0].set_ylabel('D$_{0_2}$ ($cm^{2}$s$^{-1}$)');



# X axis label 
g.axes[5,0].set_xlabel('Age$_{1}$ (Ma)');
g.axes[5,1].set_xlabel('Age$_{2}$ (Ma)');
g.axes[5,2].set_xlabel('E$_{a_1}$ (kJmol$^{-1}$)');
g.axes[5,3].set_xlabel('E$_{a_2}$ (kJmol$^{-1}$)');
g.axes[5,4].set_xlabel('D$_{0_1}$ ($cm^{2}$s$^{-1}$)');
g.axes[5,5].set_xlabel('D$_{0_2}$ ($cm^{2}$s$^{-1}$)');

plt.savefig('kula_biotite_pairgrid_1.pdf')

# %%
dfx = df[-5000::4]

dfx.to_csv('kula1biotite_final.csv')
