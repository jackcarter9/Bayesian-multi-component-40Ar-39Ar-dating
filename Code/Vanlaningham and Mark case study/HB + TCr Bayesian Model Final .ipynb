# %%
import numpy as np
import matplotlib.pyplot as plt
import pymc3 as pm
from pymc3.distributions import Interpolated
from scipy import stats
import pandas as pd 
import os 
#import theano.tensor as tt
# Step 1: Import Data 
# Data in this order 
# Colums of data
# Age, Age Error, 40Ar, 39Ar, 37Ar, 36Ar, Temperature
cwd = os.chdir("/Users/jackcarter/Documents/Data_Mixtures")
df = pd.read_csv("mix_hb_tcr.csv", engine = 'python')

# %%
df.head()
# Out:
#      Age  Age Error    40Ar_r      39Ar      37Ar      36Ar  \
# 0  22.57       4.02  0.788082  0.088461  0.000423  0.005909
# 1  25.81       3.15  2.836287  0.278071  0.000424  0.014531
# 2  25.67       1.77  2.808423  0.276864  0.000425  0.007878
# 3  25.51       1.10  2.656281  0.263567  0.000157  0.004292
# 4  25.46       0.84  2.402813  0.238880  0.000158  0.002614
#
#    Temperature (Degrees Celcius)
# 0                     652.131965
# 1                     748.318352
# 2                     754.872661
# 3                     761.325348
# 4                     767.679517

# %%
# DATA
age = df['Age'].values
age_err = df['Age Error'].values
a40 = df['40Ar_r'].values
a39 = df['39Ar'].values
temp = df['Temperature (Degrees Celcius)'].values
time= 300*np.ones(len(temp))
data = age

# %%
def fracrelx(Ea, D0, a, temp, time): 
    R = 8.314e-3
    D0t = (D0/(a**2))*np.exp(-Ea/(R*temp))*time
    
    q = (6./(np.pi**(3/2)))*np.sqrt((np.pi**2)*D0t)
    
    q1 = (6./(np.pi**(1.5)))*np.sqrt((np.pi**2)*D0t)
    
    q2 = (6./(np.pi**(3/2)))*np.sqrt((np.pi**2)*D0t)\
    - (3./(np.pi**2)) *((np.pi**2)* D0t)
    
    q3 = 1 - (6./(np.pi**2)) *np.exp(-(np.pi**2)*D0t)
     
    
    
    Q = tt.switch(q <= 0.9, q2, q3)
    T = tt.switch(q < 0.1, q, Q)
    
    return T

# %%
def Increment(ea, d0, a, temp, t):
    R = 8.314e-3
    
    D0t = (d0/(a**2))*np.exp(-ea/(R*temp))*t
    
    q = (6./(np.pi**(3/2)))*np.sqrt((np.pi**2)*D0t)
    
    aa1 = np.sqrt(np.pi) * R * temp**2
    bb1 = d0*np.exp(-ea/(R*temp))*t
    z1 = (3*ea *np.sqrt(bb1/a**2))/aa1
    

    aa2 = np.sqrt(np.pi) * R *temp**2
    bb2 = d0*np.exp(-ea/(R*temp))*t
    z2 = (3*ea*(np.sqrt(bb2/a**2) - np.sqrt(np.pi)*bb2/a**2))/aa2
      
    
    aa3 = a**2 * R * temp**2
    bb3 = d0*np.exp(-ea/(R*temp))*t
    z3 = 6 * d0 * ea * t * np.exp((-np.pi**2 * bb3/a**2) - ea/(R*temp))/aa3

    
    Q = tt.switch(q <= 0.9,
                z2,
                 z3)
    
    T = tt.switch(q < 0.1, z1, Q)
    
    
    return T

# %%
def fracrel(a):
    y = np.cumsum(a)
    z = y/y.max()
    return z
data2 = fracrel(a39)

# %% [markdown]
# # Plotting Functions

# %%
import seaborn as sns
sns.set_style('ticks')
font = {"family": "Arial", 
      "size": 16, 
      "weight": "normal"}

plt.rc("font", **font)

# %%
import seaborn as sns

fig, ax = plt.subplots(1,2, figsize = (7,4))
ax[0].fill_between(data2, data - age_err, data + age_err, 
                  step = 'pre', facecolor = 'grey', alpha = 0.8, 
                  edgecolor = 'k')
ax[0].set_xlabel('Cumulative $^{39}Ar$ released')
ax[0].set_ylabel('Age (Ma)')
ax[0].set_xlim(0, 1)
ax[1].plot(temp, data2, lw = 3, color= 'k')
ax[1].set_ylabel('Cumulative $^{39}Ar$ released')
ax[1].set_xlabel('Temperature ($^{o}C$)')
plt.tight_layout()

# %%
import theano 
from theano import shared, tensor as tt
data = age
tk = temp + 273.15
time 
N = data.shape[0]
err_age = shared(age_err)
t_obs = time

# %%
y = np.random.lognormal(-4,1.6, 1000)
plt.hist(y);

# %%
W = pm.Model() 

with W: 
    
    """ Mixing Fraction for each component """
    phi = pm.Dirichlet('phi', a = np.array([0.5, 0.5]), 
                      shape = 2)

    p1 = phi[0]; p2 = phi[1]
    
    """
    Diffusion Kinetics
    Ea - Activation Energy (kJ/mol)
    D0 - Frequency Factor (ln(s^-1))
    """
    ea1 = pm.Normal('ea1', mu = 190, sd = 5)
    
    ea2 = pm.Normal('ea2', mu = 220, sd = 5)

    d01 = pm.Lognormal('d01', -4, 1)

    d02 = pm.Lognormal('d02', -3, 1)

    """ Effective Diffusion Lengthscale """

    a1 = pm.TruncatedNormal('a1', mu = 0.002, sd = 0.001, 
                           lower = 0.001, upper = 0.0032)
    a2 = pm.TruncatedNormal('a2', mu = 0.002, sd = 0.001, 
                           lower = 0.001, upper = 0.0032)

# %%
with W: 

    
    age1 = pm.Uniform('age1', lower = 0.0, 
                    upper = 4600)
    
    age2= pm.Uniform('age2', lower = 0.0, 
                    upper = 4600)

# %%
with W:
    # Mixture weights
    w1 = p1
    w2 = p2


    X = Increment(ea1, d01, a1, tk, time)
    Y = Increment(ea2, d02, a2, tk, time)
    
    YY = pm.Deterministic('YY', Y)
    XX = pm.Deterministic('XX', X)
    
    qq = w1*X + w2*Y
    mix1 = ((w1*X)/(qq))
    mix2 = ((w2*Y)/(qq))

# %%
with W:    
    #Fractional Release
    A = fracrelx(ea1, d01, a1, tk, time)
    B = fracrelx(ea2, d02, a2, tk, time)
    A = pm.Deterministic('A', A)
    B = pm.Deterministic('B', B)
    #Model
    mu1 = w1*A + w2*B
    
    #mu1 = mix1*A + mix2*B
 ############################################################################
    # Add Monontonic Constraints to all fractional release 
    for i in range(len(tk) - 1): 
        fracrel_cons = pm.Potential(f'frel_cons{i}', 
                                       tt.switch(A[i + 1] - A[i] < 0, 
                                                 -np.inf, 0) + 
                                       tt.switch(B[i + 1] - B[i] < 0, 
                                                -np.inf, 0)) 
        
    # Add Monontonic Constraints to all fractional release 
    for i in range(len(tk) - 1): 
        fracrel_cons = pm.Potential(f'frel_consbb{i}', 
                                       tt.switch(mu1[i + 1] - mu1[i] < 0, 
                                                 -np.inf, 0) + 
                                   tt.switch(mu1.max() > 1, -np.inf, 0))
###########################################################################
    # Model 
    model1 = pm.Deterministic('model1', mu1)
    # Fractional Release Equation 
    f_err1 = pm.HalfNormal('f_err1', sd = 0.005)

# %%
with W: 
    #Age Spectra Model
    mu2 = ((p1*X*age1)/(p1*X + p2*Y)) + ((p2*Y*age2)/(p1*X + p2*Y))
    
    age_err_model = pm.HalfNormal('age_err', sd = 0.2)

# %%
with W: 
    # Age Spectra Likelihood 
    obs1 = pm.Normal('obs1', mu = mu2, 
                    sd = err_age, 
                    observed = data)
    
    # Cumulative Release Likelihood
    obs2 = pm.Normal('obs2', 
                    mu = mu1, 
                    sd = f_err1, 
                    observed = data2)

# %% [markdown]
# # Check Test Probabilities

# %%
W.check_test_point();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-198-9cc97249b43e> in <module>
# ----> 1 W.check_test_point()
#
# /Applications/anaconda3/lib/python3.6/site-packages/pymc3/model.py in check_test_point(self, test_point, round_vals)
#    1026             test_point = self.test_point
#    1027
# -> 1028         return Series({RV.name:np.round(RV.logp(self.test_point), round_vals) for RV in self.basic_RVs},
#    1029             name='Log-probability of test_point')
#    1030
#
# /Applications/anaconda3/lib/python3.6/site-packages/pymc3/model.py in <dictcomp>(.0)
#    1026             test_point = self.test_point
#    1027
# -> 1028         return Series({RV.name:np.round(RV.logp(self.test_point), round_vals) for RV in self.basic_RVs},
#    1029             name='Log-probability of test_point')
#    1030
#
# /Applications/anaconda3/lib/python3.6/site-packages/pymc3/model.py in logp(self)
#     203     def logp(self):
#     204         """Compiled log probability density function"""
# --> 205         return self.model.fn(self.logpt)
#     206
#     207     @property
#
# /Applications/anaconda3/lib/python3.6/site-packages/pymc3/model.py in fn(self, outs, mode, *args, **kwargs)
#     923         Compiled Theano function
#     924         """
# --> 925         return LoosePointFunc(self.makefn(outs, mode, *args, **kwargs), self)
#     926
#     927     def fastfn(self, outs, mode=None, *args, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pymc3/model.py in makefn(self, outs, mode, *args, **kwargs)
#     908                                    on_unused_input='ignore',
#     909                                    accept_inplace=True,
# --> 910                                    mode=mode, *args, **kwargs)
#     911
#     912     def fn(self, outs, mode=None, *args, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1837                   on_unused_input=on_unused_input,
#    1838                   output_keys=output_keys,
# -> 1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
#    1841             fn = m.create(defaults)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name)
#    1517                         optimizer, inputs, outputs)
#    1518                 else:
# -> 1519                     optimizer_profile = optimizer(fgraph)
#    1520
#    1521                 end_optimizer = time.time()
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in __call__(self, fgraph)
#     106
#     107         """
# --> 108         return self.optimize(fgraph)
#     109
#     110     def add_requirements(self, fgraph):
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      95             orig = theano.tensor.basic.constant.enable
#      96             theano.tensor.basic.constant.enable = False
# ---> 97             ret = self.apply(fgraph, *args, **kwargs)
#      98         finally:
#      99             theano.tensor.basic.constant.enable = orig
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph)
#     249                     nb_nodes_before = len(fgraph.apply_nodes)
#     250                     t0 = time.time()
# --> 251                     sub_prof = optimizer.optimize(fgraph)
#     252                     l.append(float(time.time() - t0))
#     253                     sub_profs.append(sub_prof)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      95             orig = theano.tensor.basic.constant.enable
#      96             theano.tensor.basic.constant.enable = False
# ---> 97             ret = self.apply(fgraph, *args, **kwargs)
#      98         finally:
#      99             theano.tensor.basic.constant.enable = orig
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph, start_from)
#    2538                 nb = change_tracker.nb_imported
#    2539                 t_opt = time.time()
# -> 2540                 sub_prof = gopt.apply(fgraph)
#    2541                 time_opts[gopt] += time.time() - t_opt
#    2542                 sub_profs.append(sub_prof)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in apply(self, fgraph, start_from)
#    2141                     continue
#    2142                 current_node = node
# -> 2143                 nb += self.process_node(fgraph, node)
#    2144             loop_t = time.time() - t0
#    2145         finally:
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/opt.py in process_node(self, fgraph, node, lopt)
#    2072             fgraph.replace_all_validate_remove(repl_pairs,
#    2073                                                reason=lopt,
# -> 2074                                                remove=remove)
#    2075             return True
#    2076         except Exception as e:
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/toolbox.py in replace_all_validate_remove(self, fgraph, replacements, remove, reason, warn)
#     567
#     568         """
# --> 569         chk = fgraph.replace_all_validate(replacements, reason)
#     570         self._nodes_removed.update(remove)
#     571         for rm in remove:
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/toolbox.py in replace_all_validate(self, fgraph, replacements, reason, verbose)
#     516         for r, new_r in replacements:
#     517             try:
# --> 518                 fgraph.replace(r, new_r, reason=reason, verbose=False)
#     519             except Exception as e:
#     520                 msg = str(e)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/fg.py in replace(self, r, new_r, reason, verbose)
#     512         for node, i in list(r.clients):  # copy the client list for iteration
#     513             assert (node == 'output' and self.outputs[i] is r) or (node.inputs[i] is r)
# --> 514             self.change_input(node, i, new_r, reason=reason)
#     515
#     516         # sometimes the following is triggered.  If you understand why, please explain to James.
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/fg.py in change_input(self, node, i, new_r, reason)
#     450         # transaction will be reverted later.
#     451         self.execute_callbacks('on_change_input', node, i,
# --> 452                                r, new_r, reason=reason)
#     453
#     454     # replace #
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/gof/fg.py in execute_callbacks(self, name, *args, **kwargs)
#     592                 continue
#     593             tf0 = time.time()
# --> 594             fn(self, *args, **kwargs)
#     595             self.execute_callbacks_times[feature] += time.time() - tf0
#     596         self.execute_callbacks_time += time.time() - t0
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/tensor/opt.py in on_change_input(self, fgraph, node, i, r, new_r, reason)
#    1374             # owner(i.e. it is a constant or an input of the graph)
#    1375             # update_shape suppose that r and new_r are in shape_of.
# -> 1376             self.init_r(new_r)
#    1377
#    1378         # This tells us that r and new_r must have the same shape if
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/tensor/opt.py in init_r(self, r)
#    1274         if r not in self.shape_of:
#    1275             try:
# -> 1276                 self.set_shape(r, self.shape_tuple(r))
#    1277             except AttributeError:  # XXX: where would this come from?
#    1278                 self.set_shape(r, None)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/tensor/opt.py in shape_tuple(self, r)
#    1029             # This happen for NoneConst.
#    1030             return None
# -> 1031         return tuple([self.shape_ir(i, r) for i in xrange(r.ndim)])
#    1032
#    1033     def default_infer_shape(self, node, i_shapes):
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/tensor/opt.py in <listcomp>(.0)
#    1029             # This happen for NoneConst.
#    1030             return None
# -> 1031         return tuple([self.shape_ir(i, r) for i in xrange(r.ndim)])
#    1032
#    1033     def default_infer_shape(self, node, i_shapes):
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/tensor/opt.py in shape_ir(self, i, r)
#    1017         else:
#    1018             # Do not call make_node for test_value
# -> 1019             s = Shape_i(i)(r)
#    1020             try:
#    1021                 s = get_scalar_constant_value(s)
#
# /Applications/anaconda3/lib/python3.6/site-packages/theano/compile/ops.py in __init__(self, i)
#     338     __props__ = ("i",)
#     339
# --> 340     def __init__(self, i):
#     341         # As i will be used in the hash and that ndarray are not hashable,
#     342         # we need to convert it to an int as it is hashable.
#
# KeyboardInterrupt:

# %%
with W: 
    
    trace = pm.sample(20000, 
                      tune = 5000,  
                      step = pm.Metropolis())
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [age_err]
# >Metropolis: [f_err1]
# >Metropolis: [age2]
# >Metropolis: [age1]
# >Metropolis: [a2]
# >Metropolis: [a1]
# >Metropolis: [d02]
# >Metropolis: [d01]
# >Metropolis: [ea2]
# >Metropolis: [ea1]
# >Metropolis: [phi]
# Sampling 2 chains: 100%|██████████| 50000/50000 [04:11<00:00, 198.56draws/s]
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
sns.set_style('ticks')
pm.traceplot(trace[-5000:]);

# %%
print(trace['age1'][-1000:].mean(axis = 0), trace['age2'][-1000:].mean(axis = 0))
print(trace['age1'][-1000:].std(axis = 0), trace['age2'][-1000:].std(axis = 0))
# Out:
# 24.423683298737206 28.376697127368068
# 0.5086542929019189 0.24631870402454945

# %%
def percentiles(x): 
    y,z = np.percentile(x, [2.5, 97.5], 
                        axis = 0)
    q = x.mean(axis = 0)
    return print(y,x,z)

# %%
with W: 
    ppc = pm.sample_ppc(trace[-10000:], 5000)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: sample_ppc() is deprecated.  Please use sample_posterior_predictive()
#
# 100%|██████████| 5000/5000 [00:28<00:00, 178.30it/s]

# %%
f_low, f_high = np.percentile(ppc['obs2'][-2000:],
                              [2.5, 97.5],
                              axis = 0)

age_mod_low, age_mod_high = np.percentile(ppc['obs1'][-2000:], 
                                         [2.5, 97.5], 
                                         axis = 0)

zz1 = ppc['obs2'].mean(axis = 0)
zz2 = ppc['obs1'].mean(axis = 0)

# %%
# Plotting Parameters

age_low_plot = np.insert(age_mod_low, 0, age_mod_low[0])
age_high_plot = np.insert(age_mod_high, 0, age_mod_high[0])
f_mod_plot = np.insert(zz1, 0, 0)

model_plot = np.insert(zz2, 0, zz2[0])

data_err_plot = np.insert(age_err, 0, age_err[0])
data_plot = np.insert(age, 0, age[0])
f_plot = np.insert(data2, 0, 0)

# %%
fig, ax = plt.subplots(1, 2, figsize = (7, 4))
ww = data2
ax[0].fill_between(f_mod_plot, age_low_plot, 
                  age_high_plot, 
                  step = 'pre',  
                  alpha = 0.8, 
                  facecolor = 'r', 
                  label = '95% Credible\nInterval', 
                  edgecolor = 'k')

ax[0].plot(f_mod_plot, model_plot, 'r-', 
          lw = 2, 
          label = 'Mean\nPosterior\nModel', 
          drawstyle = 'steps')


ax[0].fill_between(f_plot, data_plot + data_err_plot,
                   data_plot - data_err_plot, 
        step = 'pre', alpha = 0.8, facecolor = 'grey',
          edgecolor = 'k', 
                  label = 'Data')

for i in range(len(data)): 
    ax[0].vlines(f_mod_plot, age_low_plot, 
                  age_high_plot, color = 'k', lw= 0.7)

for i in range(len(data)): 
    ax[0].vlines(f_plot, data_plot + data_err_plot,
                   data_plot - data_err_plot,  color = 'k', lw= 0.7)

ax[1].fill_between(temp, f_low, f_high, 
                  color = 'r', alpha = 0.8)

ax[1].plot(temp, zz1, '-or', 
          lw = 2, label = 'Mean\nPosterior\nModel')
ax[1].plot(temp, ww, '-ok', 
          label = 'Data')

ax[0].set_ylim(0, 40)
ax[0].set_xlim(0, 1)


ax[0].set_xlabel('Cumulative $^{39}$Ar Released')
ax[0].set_ylabel('Age (Ma)')

ax[1].set_xlabel('Temperature ($^{o}$C)')
ax[1].set_ylabel('Cumulative Release $^{39}$Ar')
ax[0].legend(fontsize = 'x-small')
ax[1].legend(fontsize = 'x-small')
plt.tight_layout()

# %% [markdown]
# # DataFrame for PairGrid

# %%
dfx = pm.trace_to_dataframe(trace[-5000:])

# %%
df_pairgrid = pd.DataFrame({"age1":dfx['age1'].values, 
                   "age2": dfx['age2'].values, 
                   "ea1":dfx['ea1'].values, 
                   "ea2":dfx['ea2'].values, 
                   "d01":dfx['d01'].values, 
                   "d02":dfx['d02'].values})

# %%
import seaborn as sns
g = sns.PairGrid(df_pairgrid)
g = g.map_diag(plt.hist, facecolor = 'grey', edgecolor = 'k', 
              alpha = 0.7)
g = g.map_offdiag(plt.scatter, alpha = 0.01, color = 'k')


# Y_AXIS LABELS

g.axes[0,0].set_ylabel('Age$_1$ (Ma)')
g.axes[1,0].set_ylabel('Age$_2$ (Ma)')
g.axes[2,0].set_ylabel('D$_0$1 ($cm^{2}s^{-1}$)')
g.axes[3,0].set_ylabel('D$_0$2 ($cm^{2}s^{-1}$)')
g.axes[4,0].set_ylabel('E$_a$1 (kJmol$^{-1}$)')
g.axes[5,0].set_ylabel('E$_a$2 (kJmol$^{-1}$)')



# X_AXIS LABELS

g.axes[5,0].set_xlabel('Age$_1$ (Ma)')
g.axes[5,1].set_xlabel('Age$_2$ (Ma)')
g.axes[5,2].set_xlabel('D$_0$1 ($cm^{2}s^{-1}$)')
g.axes[5,3].set_xlabel('D$_0$2 ($cm^{2}s^{-1}$)')
g.axes[5,4].set_xlabel('E$_a$1 (kJmol$^{-1}$)')
g.axes[5,5].set_xlabel('E$_a$2 (kJmol$^{-1}$)')

g.axes[0,0].axvspan(24.1,25.3, color = 'grey', alpha = 0.2)
g.axes[1,1].axvspan(28,28.2, color = 'grey', alpha = 0.2)
g.axes[2,2].axvspan(0.000111, 0.21,color = 'grey', alpha = 0.2)
g.axes[3,3].axvspan(0.5, 15, color = 'grey', alpha = 0.2)
g.axes[4,4].axvspan(180,200, color = 'grey', alpha = 0.2)
g.axes[5,5].axvspan(210,230, color = 'grey', alpha = 0.2)

#g.axes[4,4].set_xlim(0.11, 0.14)
#g.axes[5,5].set_xlim(3, 3.32)
#g.axes[2,2].set_xlim(193, 195.5)
#g.axes[3,3].set_xlim(215.5, 217)
#g.axes[2,2].set_ylim(0.11, 0.14)
#g.axes[4,4].set_ylim(193, 195.5)
##g.axes[5,5].set_ylim(215.5, 217)

plt.tight_layout()
